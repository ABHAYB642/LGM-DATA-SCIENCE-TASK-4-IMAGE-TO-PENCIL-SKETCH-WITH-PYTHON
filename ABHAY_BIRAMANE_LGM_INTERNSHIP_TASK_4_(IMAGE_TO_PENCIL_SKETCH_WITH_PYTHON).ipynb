# %% [markdown]
# <a href="https://colab.research.google.com/github/ABHAYB642/LGM-DATA-SCIENCE-TASK-4-IMAGE-TO-PENCIL-SKETCH-WITH-PYTHON/blob/main/ABHAY_BIRAMANE_LGM_INTERNSHIP_TASK_4_(IMAGE_TO_PENCIL_SKETCH_WITH_PYTHON).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **NAME- ABHAY SANJAY BIRAMANE**
#
# ### **LETS GROW MORE SCIENCE INTERNSHIP TASK 4 (Beginner Level Task)**
#
# ### **IMAGE TO PENCIL SKETCH WITH PYTHON**

# %%
import cv2
from PIL import Image
from IPython.display import display

# %% [markdown]
# ### READ AND DISPLAY THE IMAGE

# %%
image=cv2.imread("/content/dog.jpg")
image=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
display(Image.fromarray(image))
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F6055A084D0>

# %% [markdown]
# ### CONVERT IMAGE TO GRAYSCALE

# %%
gray_image=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
display(Image.fromarray(gray_image))
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x7F6055A0D710>

# %% [markdown]
# ### CONVERT GRAYSCALE IMAGE INTO NEGATIVE IMAGE

# %%
inverted_image=cv2.bitwise_not(gray_image)
display(Image.fromarray(inverted_image))
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x7F60559A7650>

# %% [markdown]
# ### CONVERT NEGATIVE IMAGE TO BLURRY IMAGE

# %%
blurred_image=cv2.GaussianBlur(inverted_image, (21,21),0)
display(Image.fromarray(blurred_image))
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x7F6055A16390>

# %% [markdown]
# CREATE PENCIL SKETCH BY MIXING GRAYSCALE IMAGE WITH INVERTED BLURRY IMAGE

# %%
inverted_blurred = cv2.bitwise_not(blurred_image)
Pencil_Sketch = cv2.divide(gray_image,inverted_blurred,scale=250.0)
display(Image.fromarray(Pencil_Sketch))
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x7F6055929B50>

# %% [markdown]
# ### **THUS, WE HAVE CREATED A PENCIL SKETCH OF A IMAGE**

# %% [markdown]
# ### **THANKYOU**
